# %% [markdown]
# # Overview of Domestic Traffic at Major Airports

# %% [markdown]
# The US Department of Transportation provides very detailed data on historical flight data. We can analyze this data so we can buy tickets in a more informed matter.

# %% [markdown]
# ##Exploring the data

# %%
#Flights
from IPython.display import Image
#Image(filename="/home/vagrant/capstone/ipynb/v3_hubsByAirlines_jan2015_flights_viz.cys.png") 
Image(filename="/home/vagrant/capstone/ipynb/plots/Small.v3_hubsByAirlines_jan2015_flights_viz.cys.png",width=800)

# %% [markdown]
# How does the traffic look at major airports?
# One logical way to represent the data is as a graph.
# 1. Nodes are airports; the size of each node is scaled the the business of the respective airports.
# 2.  Edges represent flights between those airports; the color of the eds indicates the airline.
# 3. The 5 major U.S. Carriers are shown near their major hubs. For example, Delta's main hub is in Atlanta, and this is clear from the abundance of orange edges emerging from ATL.

# %% [markdown]
# ###Flight Cancellations
# Explore in the interactive map below to compare cancellation rates at different airports. One might imagine that airports with higher traffic and winter weather would be more susceptible to cancellations. Presumably, the three airports in the NYC area, EWR, JFK, and LGA, have the same weather. Do they have the same rate of cancellations?

# %% [markdown]
# <iframe width="100%" height="520" frameborder="0" src="https://jzangh.cartodb.com/viz/79c6a53c-06b8-11e6-824c-0e3ff518bd15/embed_map" allowfullscreen webkitallowfullscreen mozallowfullscreen oallowfullscreen msallowfullscreen></iframe>

# %% [markdown]
# ###Flight Delays
# What about Delays? Explore the interactive map below to find out delay rates as well as median delay times for your favorite (or least favorite) airports.
#
# <iframe width="100%" height="520" frameborder="0" src="https://jzangh.cartodb.com/viz/c39e17c4-0e6c-11e6-af7c-0ecfd53eb7d3/embed_map" allowfullscreen webkitallowfullscreen mozallowfullscreen oallowfullscreen msallowfullscreen></iframe>

# %%
Image(filename="/home/vagrant/capstone/ipynb/plots/AirlineByAirport_2014_clustermap.png", width=800)

# %% [markdown]
# Airports and carriers can be clustered by similarity:
#
# ['AA:American','AS:Alaska','B6:Jetblue','DL:Delta','EV:AtlanticSE','F9:Frontier','FL:Airtran',
#                   'HA:Hawaiian','MQ:AmerEagle','OO:Skywest','UA:United','US:USAirways','VX:Virgin','WN:SouthW']

# %% [markdown]
# For a quick look at the unprocessed summary data, see below.
# What patterns can we glean from this table?

# %%
delaystats.head(2)
# Out:
#    year  month carrier            carrier_name airport  \
# 0  2003      6      AA  American Airlines Inc.     ABQ
# 1  2003      6      AA  American Airlines Inc.     ANC
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  Albuquerque, NM: Albuquerque International Sun...          307         56
# 1  Anchorage, AK: Ted Stevens Anchorage Internati...           90         27
#
#    carrier_ct  weather_ct         ...           security_ct  late_aircraft_ct  \
# 0       14.68       10.79         ...                  1.48              9.96
# 1        7.09        2.00         ...                  0.00              7.16
#
#    arr_cancelled  arr_diverted   arr_delay   carrier_delay  weather_delay  \
# 0              1             1        2530             510            621
# 1              0             0        1390             271             83
#
#    nas_delay  security_delay  late_aircraft_delay
# 0        676              25                  698
# ...

# %%
#airport fight distribution
Image(filename="/home/vagrant/capstone/ipynb/plots/Histogram_of_Airport_Arrivals_2014.png",width=800)

# %% [markdown]
# As was likely apparent to you in the network figure, a small number of airports provide the vast majority of the flights. In the histogram above, airports are binned by how may arrivals they serviced in 2014. The bast majority of airports received less than 100,000 flights in 2014.

# %%
#airport fight distribution
Image(filename="/home/vagrant/capstone/ipynb/plots/ArrivalDelayBreakdown_19busiestAirports_2014.png",width=800)

# %% [markdown]
# on-time performance of airports

# %%
Image(filename="/home/vagrant/capstone/ipynb/plots/zoomed_ArrivalDelayBreakdown_19busiestAirports_2014.png",width=800)

# %% [markdown]
# Zooming in, we see that weather delays account for a surprisingly small fraction of the flights.

# %% [markdown]
# breakdown of delay types by airport

# %%
#delays by month
Image(filename="/home/vagrant/capstone/ipynb/plots/newBoxPlotsByMonth.png",width=800)

# %% [markdown]
# When we examine flight delays by month, we see some interesting patterns. There appear to be a higher rate of delayed flights in June through August, likely due to summer vacation travel, and an increase in december, perhaps due to holidays and winter weather.

# %%
#market share evolution
Image(filename="/home/vagrant/capstone/ipynb/plots/MarketShareEvolution_new.png", width=800)
#Image(url= "http://my_site.com/my_picture.jpg", width=100, height=100)

# %% [markdown]
# Due to many airport mergers in the last decade such as Airtran -> Southest, US Airways -> American Airlines, we have had fewer and fewer airlines to choose from.

# %% [markdown]
# <br />
# <br />
# <br />
# <br />
